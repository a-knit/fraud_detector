# %%
run pair.py
# Out:
# pair.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['fraud'][df['acct_type'].isin(fraud_events)] = 1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.violinplot(x=df['fraud'], y=df['channels'])

# %%
df['channels'][df.fraud==0].hist(bins=13, color='b')
df['channels'][df.fraud==1].hist(bins=13, color='r')

# %%
sns.violinplot(x=df['fraud'], y=df['falsy'])

# %%
sns.violinplot(x=df['fraud'], y=df['user_age'])

# %%
sns.violinplot(x=df['fraud'], y=df['delivery_method'])

# %%
sns.violinplot(x=df['fraud'], y=df['name_length'])

# %%
sns.violinplot(x=df['fraud'], y=df['user_type'])
plt.ylim(0, 6)
# Out:
# (0, 6)

# %%
df['user_type'][df.fraud==0].hist(bins=300, color='b')
df['user_type'][df.fraud==1].hist(bins=13, color='r')
plt.xlim(0, 6)
# Out:
# (0, 6)

# %%
sns.violinplot(x=df['fraud'], y=df['org_twitter'])
plt.ylim(-3, 18)
# Out:
# (-3, 18)

# %%
sns.violinplot(y=df['fraud'], x=df['payout_type'])

# %%
df.groupby('venue_country')['fraud'].mean()
# Out:
# venue_country
#       0.075342
# AE    0.600000
# AR    0.444444
# AT    0.000000
# AU    0.014641
# BE    0.000000
# BG    0.000000
# BR    0.000000
# BS    0.000000
# CA    0.010582
# CM    0.000000
# CN    0.000000
# CO    1.000000
# CY    1.000000
# CZ    0.000000
# DE    0.166667
# DK    1.000000
# DO    0.000000
# DZ    0.000000
# ES    0.000000
# FI    0.000000
# FR    0.269231
# GB    0.082155
# HK    0.000000
# HR    0.000000
# HT    0.000000
# HU    0.000000
# ID    0.666667
# IE    0.000000
# IL    0.000000
#         ...
# MA    1.000000
# MC    0.000000
# MX    0.000000
# MY    0.000000
# NA    1.000000
# NG    1.000000
# NI    0.000000
# NL    0.066667
# NO    0.000000
# NZ    0.000000
# OM    1.000000
# PH    0.933333
# PK    1.000000
# PL    0.000000
# PR    0.000000
# PT    0.000000
# QA    0.000000
# RE    0.000000
# RU    1.000000
# SE    0.500000
# SG    0.000000
# SK    0.000000
# TH    0.333333
# TR    0.666667
# TT    0.000000
# US    0.031190
# UY    0.000000
# ...
